# %%
import seaborn as sns
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt
import os # import the os module
# Re-import ImageDataGenerator to ensure it's available in the current scope
from tensorflow.keras.preprocessing.image import ImageDataGenerator  # Fixed: Added import statement
import tensorflow as tf
import keras
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Conv2D
from tensorflow.keras.optimizers import Adam
# !pip install keras-tuner
# Install and import keras-tuner, then replace 'kerastuner' with 'keras_tuner'
# !pip install keras-tuner  # Uncomment and run this line if you haven't installed it
from keras_tuner import RandomSearch # Fixed: Changed 'kerastuner' to 'keras_tuner'
import os
import numpy as np
import torch
import glob
import torch.nn as nn
from torchvision.transforms import transforms
from torch.utils.data import DataLoader
from torch.optim import Adam
from torch.autograd import Variable
import torchvision
import pathlib
import pandas as pd
import numpy as np
from skimage.io import imread
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from tqdm import tqdm
import torch
from torch.autograd import Variable
from torch.nn import Linear, ReLU, CrossEntropyLoss, Sequential, Conv2d, MaxPool2d, Module, Softmax, BatchNorm2d, Dropout
from torch.optim import Adam, SGD
import warnings
warnings.filterwarnings("ignore")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 4.6 MB/s eta 0:00:00
# ...

# %%
train_img = []
train_labels = []

test_img = []
test_labels = []

path_train = '/content/drive/MyDrive/7k dataset/Training' # Added trailing slash
path_test = '/content/drive/MyDrive/7k dataset/Testing'  # Added trailing slash
img_size= 300

for i in os.listdir(path_train):
    for j in os.listdir(os.path.join(path_train, i)): # Use os.path.join for correct path construction
        train_img.append(cv2.resize(cv2.imread(os.path.join(path_train, i, j)), (img_size, img_size))) # Use os.path.join for correct path construction
        train_labels.append(i)

for i in os.listdir(path_test):
    for j in os.listdir(os.path.join(path_test, i)): # Use os.path.join for correct path construction
        test_img.append(cv2.resize(cv2.imread(os.path.join(path_test, i, j)), (img_size, img_size))) # Use os.path.join for correct path construction
        test_labels.append(i)

train_img = np.array(train_img) # Moved outside the loop
test_img = np.array(test_img) # Moved outside the loop


train_labels_encoded = [0 if category == 'no_tumor' else(1 if category == 'glioma_tumor' else(2 if category=='meningioma_tumor' else 3)) for category in list(train_labels)]
test_labels_encoded = [0 if category == 'no_tumor' else(1 if category == 'glioma_tumor' else(2 if category=='meningioma_tumor' else 3)) for category in list(test_labels)]

# %%
print("Shape of train: ",(train_img).shape," and shape of test: ", (test_img).shape)
# Out:
# Shape of train:  (5722, 300, 300, 3)  and shape of test:  (1311, 300, 300, 3)

# %%
# Now use train_img and test_img
from tensorflow.keras.preprocessing.image import ImageDataGenerator

img_datagen = ImageDataGenerator(
    rotation_range=30,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.2,
    horizontal_flip=True)

img_datagen.fit(train_img)
img_datagen.fit(test_img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-953733cf7389> in <cell line: 0>()
#       9     horizontal_flip=True)
#      10
# ---> 11 img_datagen.fit(train_img)
#      12 img_datagen.fit(test_img)
#
# NameError: name 'train_img' is not defined

# %%
train_x, val_x, train_y, val_y = train_test_split(np.array(train_img), np.array(train_labels), test_size = 0.1)
train_x.shape, train_y.shape, val_x.shape, val_y.shape
