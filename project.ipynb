# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive/
# Out:
# '7k dataset'			  blood-test.csv     Iris_species_classifier.py
#  actor				  blood-train.csv    vikram
#  actor-20250128T165732Z-001.zip  'Colab Notebooks'   WA_Fn-UseC_-Telco-Customer-Churn.csv
#  amitab				  DRUV

# %%
train_dir = '/content/drive/MyDrive/7k dataset/training'  # Changed 'train' to 'training'
test_dir = '/content/drive/MyDrive/7k dataset/test'

# Verify the paths exist
import os
assert os.path.exists(train_dir), f"Training directory '{train_dir}' not found."
assert os.path.exists(test_dir), f"Testing directory '{test_dir}' not found."
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-4-f141ed5ded23> in <cell line: 0>()
#       4 # Verify the paths exist
#       5 import os
# ----> 6 assert os.path.exists(train_dir), f"Training directory '{train_dir}' not found."
#       7 assert os.path.exists(test_dir), f"Testing directory '{test_dir}' not found."
#
# AssertionError: Training directory '/content/drive/MyDrive/7k dataset/training' not found.

# %%
import os
import cv2
import numpy as np
# initially created two folders named train and test and uploaded images into it
data_path = '/content/drive/MyDrive/7k dataset'
# Function to load images and labels
def load_data_train(dataset_path):
    images = []
    labels = []
    for label, category in enumerate(['glioma', 'meningioma', 'no tumor', 'pituitary']):
        category_path = os.path.join(dataset_path, 'training', category)
        for img_file in os.listdir(category_path):
            img_path = os.path.join(category_path, img_file)
            image = cv2.imread(img_path)
            image = cv2.resize(image, (150, 150))  # Resize images to a consistent size
            images.append(image)
            labels.append(label)  # Assign 0 for akshay and 1 for ajay

    return np.array(images), np.array(labels)

# %%
DATASET_PATH = '/content/drive/MyDrive/7k dataset'  # Verify and adjust if necessary

# %%
import os
import cv2
import numpy as np

# Ensure the data_path is correct and the 'training' folder exists:
data_path = '/content/drive/MyDrive/7k dataset'

def load_data_train(dataset_path):
    images = []
    labels = []
    for label, category in enumerate(['glioma', 'meningioma', 'no tumor', 'pituitary']):
        category_path = os.path.join(dataset_path, 'training', category)

        # Print the category_path for verification:
        print(f"Checking path: {category_path}")

        # Check if the directory exists before proceeding:
        if not os.path.exists(category_path):
            print(f"Error: Directory not found - {category_path}")
            # You might want to raise an exception here or handle it differently
            continue  # Skip this category and move to the next

        for img_file in os.listdir(category_path):
            img_path = os.path.join(category_path, img_file)
            image = cv2.imread(img_path)
            image = cv2.resize(image, (150, 150))
            images.append(image)
            labels.append(label)

    return np.array(images), np.array(labels)

# Calling the function
train_images, train_labels = load_data_train(data_path)
# Out:
# Checking path: /content/drive/MyDrive/7k dataset/training/glioma
# Error: Directory not found - /content/drive/MyDrive/7k dataset/training/glioma
# Checking path: /content/drive/MyDrive/7k dataset/training/meningioma
# Error: Directory not found - /content/drive/MyDrive/7k dataset/training/meningioma
# Checking path: /content/drive/MyDrive/7k dataset/training/no tumor
# Error: Directory not found - /content/drive/MyDrive/7k dataset/training/no tumor
# Checking path: /content/drive/MyDrive/7k dataset/training/pituitary
# Error: Directory not found - /content/drive/MyDrive/7k dataset/training/pituitary

# %%
train_images, train_labels = load_data_train(data_path)  # Call the correct function name: load_data_train
# Define or import load_data_testing before calling it:
# test_images, test_labels = load_data_testing(data_path)
# Out:
# Checking path: /content/drive/MyDrive/7k dataset/training/glioma
# Error: Directory not found - /content/drive/MyDrive/7k dataset/training/glioma
# Checking path: /content/drive/MyDrive/7k dataset/training/meningioma
# Error: Directory not found - /content/drive/MyDrive/7k dataset/training/meningioma
# Checking path: /content/drive/MyDrive/7k dataset/training/no tumor
# Error: Directory not found - /content/drive/MyDrive/7k dataset/training/no tumor
# Checking path: /content/drive/MyDrive/7k dataset/training/pituitary
# Error: Directory not found - /content/drive/MyDrive/7k dataset/training/pituitary

# %%
import tensorflow as tf

# Define your model architecture here
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(4, activation='softmax')  # 4 output classes
])

# Now you can compile your model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define the data generators for training and testing
train_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# Define the train and test directories
train_dir = 'path_to_train_data'  # Make sure this is the correct path
test_dir = 'path_to_test_data'    # Make sure this is the correct path

# Create the generators
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(150, 150),
    batch_size=32,
    class_mode='binary'
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(150, 150),
    batch_size=32,
    class_mode='binary'
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-34-3366f546ceac> in <cell line: 0>()
#      10
#      11 # Create the generators
# ---> 12 train_generator = train_datagen.flow_from_directory(
#      13     train_dir,
#      14     target_size=(150, 150),
#
# /usr/local/lib/python3.11/dist-packages/keras/src/legacy/preprocessing/image.py in flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio)
#    1136         keep_aspect_ratio=False,
#    1137     ):
# -> 1138         return DirectoryIterator(
#    1139             directory,
#    1140             self,
#
# ...

# %%
history = model.fit(
    train_generator,  # Training data
    validation_data=test_generator,  # Testing data
    epochs=10,  # You can increase this for better accuracy
    verbose=1
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-de99955600d2> in <cell line: 0>()
#       1 history = model.fit(
# ----> 2     train_generator,  # Training data
#       3     validation_data=test_generator,  # Testing data
#       4     epochs=10,  # You can increase this for better accuracy
#       5     verbose=1
#
# NameError: name 'train_generator' is not defined

# %%
model.save('/content/drive/MyDrive/brain_tumor_model.h5')

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy
plt.figure(figsize=(12, 4))

# Accuracy Plot
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.title('Model Accuracy')

# Loss Plot
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title('Model Loss')

plt.show()

# %%
import numpy as np
from tensorflow.keras.preprocessing import image

# Load an image for testing (Change this to your image path)
img_path = '/content/drive/MyDrive/sample_brain_mri.jpg'
img = image.load_img(img_path, target_size=(150, 150))

# Convert the image to an array
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0) / 255.0  # Normalize

# Make prediction
prediction = model.predict(img_array)

# Class labels
class_names = ['Glioma', 'Meningioma', 'No Tumor', 'Pituitary']
predicted_class = class_names[np.argmax(prediction)]

print(f"Prediction: {predicted_class}")
